# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
data= tf.keras.datasets.cifar10
(train_image,train_label),(test_image,test_label)= data.load_data()
print(train_image.shape)
print(test_image.shape)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
train_image= train_image/255.0
test_image= test_image/255.0

# %%
model= tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32,(3,3), activation='relu', input_shape= (32,32,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64,(3,3), activation='relu', input_shape= (32,32,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64,(3,3), activation='relu', input_shape= (32,32,3)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(10,activation='softmax')
    
])
model.compile(loss= 'sparse_categorical_crossentropy', metrics= ['accuracy'], optimizer= 'Adam')

# %%
history = model.fit(train_image,train_label,epochs=29, validation_data= (test_image,test_label))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/20
# 50000/50000 [==============================] - 8s 154us/sample - loss: 2.3028 - accuracy: 0.0995 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/20
# 50000/50000 [==============================] - 8s 169us/sample - loss: 2.3028 - accuracy: 0.0981 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/20
# 50000/50000 [==============================] - 8s 158us/sample - loss: 2.3028 - accuracy: 0.0952 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 4/20
# 41440/50000 [=======================>......] - ETA: 1s - loss: 2.3028 - accuracy: 0.0965

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend()
